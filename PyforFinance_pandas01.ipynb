# %%
from pandas_datareader import data as web
import matplotlib.pyplot as plt

# %%
df = web.DataReader("BAC", "iex", 2016-1-1, 2017-1-1)
df.head()
# Out:
# 5y
#                open     high      low    close     volume
# date
# 2014-01-02  14.7281  15.1693  14.7187  15.1130  149225696
# 2014-01-03  15.2726  15.4885  15.2350  15.4040  130054547
# 2014-01-06  15.6058  15.7044  15.5448  15.6387  114727379
# 2014-01-07  15.7419  15.7607  15.4415  15.4885  112141137
# 2014-01-08  15.6480  15.6668  15.5064  15.5636  101227932

# %%
df['close'].plot(figsize=(8,5))
